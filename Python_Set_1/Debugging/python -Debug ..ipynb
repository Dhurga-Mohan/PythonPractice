# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)
     
#Answer
# : is missing at the end of for  (expected ':')

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

#Answer
#Error during compilation. int and str cannot be concadinated.

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b
#Answer
# :  is missing at the end of def (expected ':')

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

#Answer
# index out of bound. There are only 4 values in list starts with 0 to 3. So 4 th position won't have data. It will give error

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

#Answer
#() braces is missing for print statement (Missing parentheses

# %%
#6.Find the error in the following Python code:
x = 5 / 0

#Answer
#We cannot do divide by zero . It will give divide by zero error

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

#Answer
# the variable name is not defined in the memory. 'name' is not defined

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

#Answer
#First thing is there won't be any error while running this. There won't be any putput gets printed.
#Python realizes it cannot reach 10 by going downward, so it immediately returns an empty sequence.
#If we need to print rever we have give like this range(10,1,-1)

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

#Answer
# if x = 5 is wrong. = is assignment operator. == is used to check the equality. So it will give invalid syntax. 
# Correct condition : if x==5 :

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)


#Answer
# function should be defined with : at last.
