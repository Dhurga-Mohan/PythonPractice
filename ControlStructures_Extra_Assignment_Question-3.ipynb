# %%
inputVal = int(input("value:"))
if(inputVal == 10):
    print("CORRECT")
# Out:
# value: 12

# %%
passVal = input("Enter the password:")
if passVal == "HOPE@123":
    print("CORRECT")
else:
    print("INCORRECT")
# Out:
# Enter the password: HOPE@123
# CORRECT

# %%
ageVal = int(input("Enter Age"))
print("Age:",ageVal)
if(ageVal <= 12):
    print("Children")
elif(ageVal <= 19):
    print("Teenager")
elif(ageVal <= 30):
    print("Adult")
elif(ageVal <= 59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Enter Age 20
# Age: 20
# Adult

# %%
numVal = int(input("Enter any number:"))
if(numVal >0 ):
    print("No is positive")
else:
    print("No is Negative")
# Out:
# Enter any number: 1
# No is positive

# %%
numValDiv5 = int(input("Enter a number to check:"))
if(numValDiv5%5 == 0):
    print("No is divisible by 5")
else:
    print("No is not divisible by 5")
