# %%
from multipleClassPractice import SubfieldsInAI,OddEven,ElegiblityForMarriage,FindPercentAndTriangle

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
OddEven.OddEven()
# Out:
# Enter a number: 5242
# 5242 is Even number

# %%
ElegiblityForMarriage.Elegible()
# Out:
# Your Gender: Male
# Your Age: 32
# ELIGIBLE

# %%
FindPercentAndTriangle.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.60000000000001

# %%
FindPercentAndTriangle.triangle()
