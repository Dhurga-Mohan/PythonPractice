# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
instituteName = input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
schoolName = input("Enter your school name:")
degree = input("Enter your degree:")
# Out:
# Enter your name: Dhurga
# Enter your age: 28
# Enter your school name: Town Higher Secondary School
# Enter your degree: MCA

# %%
a = 43
b = 34
sub = a - b
print("Sub =",sub)
# Out:
# Sub = 9

# %%
a= 63 
b= 97
Mul = a * b
print("Mul = ",Mul)
# Out:
# Mul =  6111

# %%
a= 76 
b= 31
floatDiv = a/b
print("Float Div =", floatDiv)
# Out:
# Float Div = 2.4516129032258065

# %%
a= 76 
b= 31
floorDiv = a//b
print("Floor Div = ", floorDiv)
# Out:
# Floor Div =  2

# %%
a= 76 
b= 31
modulo = a % b
print("Modulo = ",modulo)
# Out:
# Modulo =  14

# %%
a= 4 
b= 4 
powValue = a**b
print("Power = ",powValue)
# Out:
# Power =  0
